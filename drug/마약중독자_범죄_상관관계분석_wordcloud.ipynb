# %%
import pandas as pd

# %%
df=pd.read_excel("./마약소계.xlsx")

# %%
df.head()
# Out:
#   범죄대분류  범죄중분류  2014  2015  2016 2017
# 0  강력범죄   살인기수     2     0     1    -
# 1  강력범죄  살인미수등     5     0     0    1
# 2  강력범죄     강도    13     6     2    2
# 3  강력범죄     강간    14    13     6    8
# 4  강력범죄   유사강간     2     1     0    -

# %%
for i in range(0,len(df)):
    if df[2017][i]=="-":
        df[2017][i]=0
        
df.head()
# Out:
# C:\Users\202-006\Anaconda3\lib\site-packages\ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#   범죄대분류  범죄중분류  2014  2015  2016 2017
# 0  강력범죄   살인기수     2     0     1    0
# 1  강력범죄  살인미수등     5     0     0    1
# 2  강력범죄     강도    13     6     2    2
# 3  강력범죄     강간    14    13     6    8
# 4  강력범죄   유사강간     2     1     0    0

# %%
df.to_excel("마약.xlsx")

# %%
df=pd.read_excel("마약.xlsx")
len(df)
# Out:
# 38

# %%
a=df.iloc[:,0:2]
len(a)
# Out:
# 38

# %%
a=pd.concat([a,a,a,a])
len(a)
# Out:
# 152

# %%
year=[]
z=[]

# %%
for i in range(2014,2018):
    for j in range(0,len(df)):
        year.append(i)
        z.append(df[i][j])

# %%
len(z)
# Out:
# 152

# %%
a1=pd.DataFrame({"year":year,"cnt":z})
a1.head()
# Out:
#    year  cnt
# 0  2014    2
# 1  2014    5
# 2  2014   13
# 3  2014   14
# 4  2014    2

# %%
a.to_excel("ma1.xlsx")
a1.to_excel("ma2.xlsx")

# %% [markdown]
# # wordcloud

# %%
# !pip install pytagcloud

# %%
# !pip install pygame
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/ed/56/b63ab3724acff69f4080e54c4bc5f55d1fbdeeb19b92b70acf45e88a5908/pygame-1.9.6-cp37-cp37m-win_amd64.whl
# ...

# %%
# !pip install wordcloud
# Out:
# ...
#   Using cached https://files.pythonhosted.org/packages/23/4e/1254d26ce5d36facdcbb5820e7e434328aed68e99938c75c9d4e2fee5efb/wordcloud-1.5.0-cp37-cp37m-win_amd64.whl
# ...

# %%
import pytagcloud
import pandas as pd
import pytagcloud as tagcloud
from IPython.display import Image 
import matplotlib.pyplot as plt
from wordcloud import WordCloud

# %%
df1=pd.read_excel("./ma6.xlsx")
df2=pd.read_excel("./ma9.xlsx")
df3=pd.read_excel("./ma10.xlsx")

# %%
d = {}
for a,b,c,z in df3.values:
    d[b] = z

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',background_color="black")
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()

# %%
d = {}
for a,b,c,z in df2.values:
    d[b] = z

import matplotlib.pyplot as plt
from wordcloud import WordCloud

wordcloud = WordCloud(font_path='C:\\Windows\\Fonts\\malgun.ttf',background_color="black")
wordcloud.generate_from_frequencies(frequencies=d)
plt.figure(figsize=(20, 16))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis("off")
plt.show()
