# %%
# !pip install google_images_download
# Out:
# ...
#   Stored in directory: C:\Users\cloud\AppData\Local\pip\Cache\wheels\1f\28\ad\f56e7061e1d2a9a1affe2f9c649c2570cb9198dd24ede0bbab
# Successfully built google-images-download
# ...

# %%
from google_images_download import google_images_download
 
import ssl  # ssl Error 발생 시
ssl._create_default_https_context = ssl._create_unverified_context  
 
def imageCrawling(keyword, dir):
    
    response = google_images_download.googleimagesdownload()
 
    arguments = {"keywords":keyword,      # 검색 키워드
                 "limit":10000,             # 크롤링 이미지 수
                 "print_urls":True,       # 이미지 url 출력
                 "no_directory":True,     # 
                 'output_directory':dir,
                 'chromedriver':'./driver/chromedriver.exe'}  # 크롤링 이미지를 저장할 폴더
 
    paths = response.download(arguments)
    print(paths)

# %%
imageCrawling('leopard','./표범/') # imageCrawling('검색어', '저장경로')

#Unfortunately all 10000 could not be downloaded because some images were not downloadable. 369 is all we got for this search filter!
#Errors: 31
# Out:
# Item no.: 1 --> Item name = leopard
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: http://mnzoo.org/wp-content/uploads/2013/08/leopard11.jpg
# URLError on an image...trying next one... Error: HTTP Error 403: Forbidden
# Image URL: https://qph.fs.quoracdn.net/main-qimg-3e8f7ddc15255d57908dfe39c3b9838e.webp
# Completed Image ====> 1.main-qimg-3e8f7ddc15255d57908dfe39c3b9838e.webp
# Image URL: https://upload.wikimedia.org/wikipedia/commons/a/a1/Namibie_Etosha_Leopard_01edit.jpg
# Completed Image ====> 2.Namibie_Etosha_Leopard_01edit.jpg
# Image URL: https://cdn.britannica.com/30/136130-050-3370E37A/Leopard.jpg
# Completed Image ====> 3.Leopard.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/6/65/I_See_You.jpg
# Completed Image ====> 4.I_See_You.jpg
# Image URL: https://ichef.bbci.co.uk/news/660/cpsprodpb/D8BD/production/_107258455_gettyimages-924737158-1.jpg
# ...

# %%
imageCrawling('zebra','./얼룩말/')
# Out:
# Item no.: 1 --> Item name = zebra
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://thumbor.forbes.com/thumbor/960x0/https%3A%2F%2Fblogs-images.forbes.com%2Fjamiecartereurope%2Ffiles%2F2019%2F02%2F1-2-1200x675.jpg
# Completed Image ====> 1.https%3A%2F%2Fblogs-images.forbes.com%2Fjamiecartereurope%2Ffiles%2F2019%2F02%2F1-2-1200x675.jpg
# Image URL: https://images.unsplash.com/photo-1526319238109-524eecb9b913?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&w=1000&q=80
# Invalid or missing image format. Skipping...
# Image URL: http://www.thetimes.co.uk/imageserver/image/methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Fac5d1a26-d95a-11e9-9cfd-b79996a387b0.jpg?crop=1814%2C1020%2C78%2C232&resize=685
# Completed Image ====> 2.methode%2Ftimes%2Fprod%2Fweb%2Fbin%2Fac5d1a26-d95a-11e9-9cfd-b79996a387b0.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/9/96/Common_zebra_1.jpg
# ...

# %%
imageCrawling("horse","./말/")
# Out:
# Item no.: 1 --> Item name = horse
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://thehorse.com/wp-content/uploads/2017/01/iStock-510488648.jpg
# Completed Image ====> 1.iStock-510488648.jpg
# Image URL: https://thehorse.com/wp-content/uploads/2017/09/paint-horse-running-in-field.jpg
# Completed Image ====> 2.paint-horse-running-in-field.jpg
# Image URL: https://images2.minutemediacdn.com/image/upload/c_crop,h_1194,w_2121,x_0,y_34/f_auto,q_auto,w_1100/v1553786510/shape/mentalfloss/539787-istock-879570436.jpg
# Completed Image ====> 3.539787-istock-879570436.jpg
# Image URL: https://www.telegraph.co.uk/content/dam/news/2019/01/12/TELEMMGLPICT000185347942_trans_NvBQzQNjv4Bq4k9pB6mVv575RZMUuuHUNjlaTMTxUhlzF8Rkw038U-A.jpeg?imwidth=450
# Completed Image ====> 4.TELEMMGLPICT000185347942_trans_NvBQzQNjv4Bq4k9pB6mVv575RZMUuuHUNjlaTMTxUhlzF8Rkw038U-A.jpeg
# ...

# %%
imageCrawling("hippopotamus","./하마/")
# Out:
# Item no.: 1 --> Item name = hippopotamus
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/b/b3/Hipop%C3%B3tamo_%28Hippopotamus_amphibius%29%2C_parque_nacional_de_Chobe%2C_Botsuana%2C_2018-07-28%2C_DD_82.jpg
# Completed Image ====> 1.Hipop%C3%B3tamo_%28Hippopotamus_amphibius%29%2C_parque_nacional_de_Chobe%2C_Botsuana%2C_2018-07-28%2C_DD_82.jpg
# Image URL: https://resize.hswstatic.com/w_907/gif/hippo-sunscreen.jpg
# Completed Image ====> 2.hippo-sunscreen.jpg
# Image URL: https://c402277.ssl.cf1.rackcdn.com/photos/16937/images/hero_small/Medium_WW1113453.jpg?1551472667
# Completed Image ====> 3.Medium_WW1113453.jpg
# Image URL: https://animals.sandiegozoo.org/sites/default/files/2016-09/animals_hero_pygmy_hippo.jpg
# Completed Image ====> 4.animals_hero_pygmy_hippo.jpg
# ...

# %%
imageCrawling("crocodile","./악어1/")
# Out:
# Item no.: 1 --> Item name = crocodile
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://scx1.b-cdn.net/csz/news/800/2019/28-newspeciesof.jpg
# Completed Image ====> 1.28-newspeciesof.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/b/bd/Nile_crocodile_head.jpg
# Completed Image ====> 2.Nile_crocodile_head.jpg
# Image URL: https://www.thoughtco.com/thmb/X2tigzLPQ7Fos9_LjzqSWwiBQiI=/768x0/filters:no_upscale():max_bytes(150000):strip_icc()/GettyImages-822539340-5c80189c46e0fb00019b8ec4.jpg
# Completed Image ====> 3.GettyImages-822539340-5c80189c46e0fb00019b8ec4.jpg
# Image URL: https://upload.wikimedia.org/wikipedia/commons/5/58/Crocodilia_montage.jpg
# Completed Image ====> 4.Crocodilia_montage.jpg
# Image URL: https://www.abc.net.au/news/image/11368074-3x2-700x467.jpg
# Completed Image ====> 5.11368074-3x2-700x467.jpg
# ...

# %%
imageCrawling("alligator","./악어2/")
# Out:
# Item no.: 1 --> Item name = alligator
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/0/03/American_Alligator.jpg
# Completed Image ====> 1.American_Alligator.jpg
# Image URL: https://news.wttw.com/sites/default/files/styles/full/public/article/image-non-gallery/Alligator%201_0711.jpg?itok=QbxFAfy4
# Completed Image ====> 2.Alligator%201_0711.jpg
# Image URL: https://thenypost.files.wordpress.com/2019/07/florida-2nd-alligaotr-attack.jpg?quality=90&strip=all&w=618&h=410&crop=1
# Completed Image ====> 3.florida-2nd-alligaotr-attack.jpg
# Image URL: https://images.complex.com/complex/images/c_limit,dpr_auto,q_90,w_720/fl_lossy,pg_1/pelndjagxsy2d6r62ura/alligator
# Invalid or missing image format. Skipping...
# Image URL: https://cdn.mos.cms.futurecdn.net/2S7VFinEf5gYvcXD8cD8T8-320-80.jpg
# Completed Image ====> 4.2S7VFinEf5gYvcXD8cD8T8-320-80.jpg
# ...

# %%
imageCrawling("kangaroo","./캥거루/")
# Out:
# Item no.: 1 --> Item name = kangaroo
# Evaluating...
# Getting you a lot of images. This may take a few moments...
# Reached end of Page.
# Starting Download...
# Image URL: https://upload.wikimedia.org/wikipedia/commons/0/0c/Kangaroo_Australia_01_11_2008_-_retouch.JPG
# Completed Image ====> 1.Kangaroo_Australia_01_11_2008_-_retouch.JPG
# Image URL: https://media.australianmuseum.net.au/media/dd/images/eastern_grey_kangaroo.8d02488.width-800.cdc7286.jpg
# Completed Image ====> 2.eastern_grey_kangaroo.8d02488.width-800.cdc7286.jpg
# Image URL: https://images.unsplash.com/photo-1551270988-87c5ea57cdfe?ixlib=rb-1.2.1&ixid=eyJhcHBfaWQiOjEyMDd9&w=1000&q=80
# Invalid or missing image format. Skipping...
# Image URL: https://cdn.mos.cms.futurecdn.net/ETb2xLjvc62eb7PPLspSsU-320-80.jpg
# Completed Image ====> 3.ETb2xLjvc62eb7PPLspSsU-320-80.jpg
# ...

# %%
imageCrawling("koala","./코알라/")

# %%
imageCrawling("elephant","./코끼리/")

# %%
imageCrawling("snake","뱀")

# %%
imageCrawling("deer","사슴")

# %%
imageCrawling()
